# %%
import pandas as pd

# Display all columns
pd.set_option('display.max_columns', None)

df_countries_meta = pd.read_csv('world_countries_meta-data.csv')
print(df_countries_meta.shape)
df_countries_meta.head(14)
# Out:
# (251, 40)
#    FIPS_10_ ISO_A2 ISO_A3 CIOC  UN_A3 Calling Codes Top Level Domain  \
# 0        AF     AF    AFG  AFG      4        ['93']          ['.af']
# 1        AL     AL    ALB  ALB      8       ['355']          ['.al']
# 2        AG     DZ    DZA  ALG     12       ['213']          ['.dz']
# 3        AQ     AS    ASM  ASA     16         ['1']          ['.as']
# 4        AN     AD    AND  AND     20       ['376']          ['.ad']
# 5        AO     AO    AGO  ANG     24       ['244']          ['.ao']
# 6        AV     AI    AIA  NaN    660         ['1']          ['.ai']
# 7        AC     AG    ATG  ANT     28         ['1']          ['.ag']
# 8        AR     AR    ARG  ARG     32        ['54']          ['.ar']
# 9        AM     AM    ARM  ARM     51       ['374']          ['.am']
# 10       AA     AW    ABW  ARU    533       ['297']          ['.aw']
# 11       AS     AU    AUS  AUS     36        ['61']          ['.au']
# ...

# %%
df_country_toExclude = df_countries_meta[df_countries_meta["FIPS_10_"] == "-99" ]
df_country_toExclude.shape
# Out:
# (16, 40)

# %%
df_countries_toKeep = df_countries_meta[df_countries_meta["FIPS_10_"] != "-99" ]
df_countries_toKeep.shape
# Out:
# (235, 40)

# %%
df_countries_meta.values[22]
# Out:
# array(['BN', 'BJ', 'BEN', 'BEN', 204, "['229']", "['.bj']",
#        "['UTC+01:00']", 'Porto-Novo', 'Beninese', 'Republic', 'Benin',
#        'Bénin', 'Republic of Benin', 'Benin', 'Benin', 'Bénin', 'Africa',
#        'Africa', 'Sub-Saharan Africa', 'AFR', 'Western Africa',
#        'Sovereign country', '7. Least developed region', '5. Low income',
#        "[{'code': 'XOF', 'name': 'West African CFA franc', 'symbol': 'Fr'}]",
#        "['BJ', 'Republic of Benin', 'République du Bénin']",
#        "[{'iso639_1': 'fr', 'iso639_2': 'fra', 'name': 'French', 'nativeName': 'français'}]",
#        "{'br': 'Benin', 'pt': 'Benim', 'nl': 'Benin', 'hr': 'Benin', 'fa': 'بنین', 'de': 'Benin', 'es': 'Benín', 'fr': 'Bénin', 'ja': 'ベナン', 'it': 'Benin', 'hu': 'Benin'}",
#        "['BFA', 'NER', 'NGA', 'TGO']",
#        "[{'acronym': 'AU', 'name': 'African Union', 'otherNames': ['الاتحاد الأفريقي', 'Union africaine', 'União Africana', 'Unión Africana', 'Umoja wa Afrika']}]",
# ...

# %%
df_countries_meta.columns
# Out:
# Index(['FIPS_10_', 'ISO_A2', 'ISO_A3', 'CIOC', 'UN_A3', 'Calling Codes',
#        'Top Level Domain', 'Timezones', 'Capital', 'Demonym', 'GovernmentForm',
#        'Name', 'Native Name', 'FORMAL_EN', 'WB_NAME', 'NAME_EN', 'NAME_FR',
#        'CONTINENT', 'REGION_UN', 'REGION_WB', 'WB_REGION', 'Subregion', 'TYPE',
#        'ECONOMY', 'INCOME_GRP', 'Currencies', 'Alt Spellings', 'Languages',
#        'Translations', 'Borders', 'Regional Blocs', 'IndepYear',
#        'LifeExpectancy', 'Area', 'SurfaceArea', 'Shape_Area', 'Shape_Leng',
#        'Latlng', 'geometry', 'Flag'],
#       dtype='object')

# %%
df_countries_meta['INCOME_GRP'].value_counts()
# Out:
# INCOME_GRP
# 4. Lower middle income     58
# 3. Upper middle income     58
# 5. Low income              50
# 2. High income: nonOECD    46
# 1. High income: OECD       39
# Name: count, dtype: int64

# %%
df_countries_meta['CONTINENT'].value_counts()
# df_countries_meta['REGION_UN'].value_counts()
# Out:
# CONTINENT
# Europe                     53
# Africa                     52
# Asia                       51
# North America              48
# Oceania                    25
# South America              13
# Seven seas (open ocean)     9
# Name: count, dtype: int64

# %%
df_countries_meta['REGION_WB'].value_counts()
# Out:
# REGION_WB
# Europe & Central Asia         63
# East Asia & Pacific           54
# Sub-Saharan Africa            52
# Latin America & Caribbean     48
# Middle East & North Africa    21
# South Asia                     8
# North America                  4
# Antarctica                     1
# Name: count, dtype: int64

# %%
df_countries_meta['Subregion'].value_counts()
# Out:
# Subregion
# Caribbean                    25
# Southern Europe              17
# Western Asia                 17
# Western Africa               17
# Eastern Africa               16
# Northern Europe              13
# South America                13
# South-Eastern Asia           11
# Middle Africa                10
# Southern Asia                 9
# Polynesia                     9
# Western Europe                8
# Central Europe                8
# Eastern Asia                  7
# Micronesia                    7
# Central America               7
# Northern Africa               6
# Southern Africa               6
# Eastern Europe                6
# Northern America              5
# Central Asia                  5
# Melanesia                     5
# Australia and New Zealand     4
# North America                 1
# Name: count, dtype: int64

# %%
df_countries_meta['TYPE'].value_counts()
# Out:
# TYPE
# Sovereign country    185
# Dependency            41
# Country               23
# Lease                  1
# Disputed               1
# Name: count, dtype: int64

# %%
df_countries_meta['ECONOMY'].value_counts()
# Out:
# ECONOMY
# 6. Developing region          100
# 7. Least developed region      62
# 2. Developed region: nonG7     54
# 5. Emerging region: G20        20
# 1. Developed region: G7         7
# 3. Emerging region: BRIC        4
# 4. Emerging region: MIKT        4
# Name: count, dtype: int64

# %%
df_countries_meta['GovernmentForm'].value_counts()
# Out:
# GovernmentForm
# Republic                                        119
# Constitutional Monarchy                          32
# Federal Republic                                 14
# Dependent Territory of the UK                    12
# Dependent Territory of the US                     9
# Monarchy                                          5
# Nonmetropolitan Territory of France               4
# Constitutional Monarchy, Federation               3
# Socialistic Republic                              3
# US Territory                                      3
# Part of Denmark                                   2
# Territory of Australia                            2
# Monarchy (Sultanate)                              2
# Nonmetropolitan Territory of New Zealand          2
# Islamic Republic                                  2
# Commonwealth of the US                            2
# Special Administrative Region of China            2
# Parliamentary Coprincipality                      1
# ...
