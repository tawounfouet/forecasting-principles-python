# %%
"https://www.data.gouv.fr/fr/datasets/demandes-de-valeurs-foncieres/#/resources/87038926-fb31-4959-b2ae-7a24321c599a"


"https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20231010-093059/valeursfoncieres-2022.txt"

"https://www.data.gouv.fr/fr/datasets/r/87038926-fb31-4959-b2ae-7a24321c599a"
# Out:
# 'https://www.data.gouv.fr/fr/datasets/r/87038926-fb31-4959-b2ae-7a24321c599a'

# %% [markdown]
# ## À propos de cette application
# Cette application est proposée par l’équipe de data.gouv.fr, et permet de visualiser les données de demandes de valeurs foncières (DVF) publiée et produites par la direction générale des finances publiques.
# Ces données sont issues des actes notariés et des informations cadastrales et permettent de connaître les transactions immobilières intervenues au cours des cinq dernières années sur le territoire métropolitain et les DOM-TOM, à l’exception de l’Alsace, de la Moselle et de Mayotte.
# Vous pouvez télécharger et exploiter les données brutes selon les conditio

# %%
import pandas as pd

# URL of the CSV text file
url = "https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20231010-093059/valeursfoncieres-2022.txt"

# Read the CSV file into a DataFrame
#df = pd.read_csv(url, sep='|', encoding='latin1')

# Display the first few rows of the DataFrame
#print(df.head())

# %%
import pandas as pd
from urllib.request import urlopen

# URL of the CSV text file
url = "https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20231010-093059/valeursfoncieres-2022.txt"

# Read the CSV file into a DataFrame
with urlopen(url) as response:
    df = pd.read_csv(response, sep='|', encoding='latin1')

# Display the first few rows of the DataFrame
display(df.head())
# Out:
# /var/folders/8y/dhqjv_h574s900xmlg8w791r0000gn/T/ipykernel_14586/733954181.py:9: DtypeWarning: Columns (18,23,24,26,28,29,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(response, sep='|', encoding='latin1')
#    Identifiant de document  Reference document  1 Articles CGI  \
# 0                      NaN                 NaN             NaN
# 1                      NaN                 NaN             NaN
# 2                      NaN                 NaN             NaN
# 3                      NaN                 NaN             NaN
# 4                      NaN                 NaN             NaN
#
#    2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# ...

# %%
import pandas as pd

# Display all columns
pd.set_option('display.max_columns', None)


df_text = pd.read_csv('valeursfoncieres-2022.txt', sep='|')
# Out:
# /var/folders/8y/dhqjv_h574s900xmlg8w791r0000gn/T/ipykernel_3775/196701742.py:7: DtypeWarning: Columns (23,24,26,29,31,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_text = pd.read_csv('valeursfoncieres-2022.txt', sep='|')

# %%
df_text.shape
# Out:
# (1019692, 43)

# %%
df_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019692 entries, 0 to 1019691
# Data columns (total 43 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   Identifiant de document     0 non-null        float64
#  1   Reference document          0 non-null        float64
#  2   1 Articles CGI              0 non-null        float64
#  3   2 Articles CGI              0 non-null        float64
#  4   3 Articles CGI              0 non-null        float64
#  5   4 Articles CGI              0 non-null        float64
#  6   5 Articles CGI              0 non-null        float64
#  7   No disposition              1019692 non-null  int64
#  8   Date mutation               1019692 non-null  object
#  9   Nature mutation             1019692 non-null  object
#  10  Valeur fonciere             1014834 non-null  object
#  11  No voie                     592261 non-null   float64
# ...

# %%
df_text.columns
# Out:
# Index(['Identifiant de document', 'Reference document', '1 Articles CGI',
#        '2 Articles CGI', '3 Articles CGI', '4 Articles CGI', '5 Articles CGI',
#        'No disposition', 'Date mutation', 'Nature mutation', 'Valeur fonciere',
#        'No voie', 'B/T/Q', 'Type de voie', 'Code voie', 'Voie', 'Code postal',
#        'Commune', 'Code departement', 'Code commune', 'Prefixe de section',
#        'Section', 'No plan', 'No Volume', '1er lot',
#        'Surface Carrez du 1er lot', '2eme lot', 'Surface Carrez du 2eme lot',
#        '3eme lot', 'Surface Carrez du 3eme lot', '4eme lot',
#        'Surface Carrez du 4eme lot', '5eme lot', 'Surface Carrez du 5eme lot',
#        'Nombre de lots', 'Code type local', 'Type local', 'Identifiant local',
#        'Surface reelle bati', 'Nombre pieces principales', 'Nature culture',
#        'Nature culture speciale', 'Surface terrain'],
#       dtype='object')

# %%
df_text[['Date mutation', 'Nature mutation', 'Valeur fonciere',
        'Type de voie', 'Code voie', 'Voie', 'Code postal',
       'Commune', 'Code departement', 'Code commune', 'Prefixe de section',
       'Section', 'No plan', 'Nombre de lots', 'Code type local', 'Type local', 
       'Surface reelle bati', 'Nombre pieces principales', 'Nature culture',
       'Surface terrain']].head()
# Out:
#   Date mutation Nature mutation Valeur fonciere Type de voie Code voie  \
# 0    03/01/2022           Vente        55000,00          RUE      2280
# 1    03/01/2022           Vente       143000,00          NaN      B010
# 2    03/01/2022           Vente       143000,00          NaN      B010
# 3    03/01/2022           Vente       143000,00          RTE      0055
# 4    04/01/2022           Vente          300,00          NaN      B031
#
#             Voie  Code postal            Commune  Code departement  \
# 0  DE LA LIBERTE       1000.0    BOURG-EN-BRESSE                 1
# 1   CHAMP COCHET       1480.0          SAVIGNEUX                 1
# 2   CHAMP COCHET       1480.0          SAVIGNEUX                 1
# 3   DE LA DOMBES       1480.0          SAVIGNEUX                 1
# 4    AUX PIERRES       1480.0  MESSIMY SUR SAONE                 1
#
#    Code commune  Prefixe de section Section  No plan  Nombre de lots  \
# ...

# %%
df_text[['Code postal','Commune', 'Code departement', 'Code commune']].describe(include='all')
# Out:
#          Code postal  Commune  Code departement  Code commune
# count   1.014644e+06  1019692      1.019692e+06  1.019692e+06
# unique           NaN     8484               NaN           NaN
# top              NaN     NICE               NaN           NaN
# freq             NaN    26624               NaN           NaN
# mean    1.333739e+04      NaN      1.301652e+01  1.984790e+02
# std     7.061255e+03      NaN      7.037098e+00  1.570108e+02
# min     1.000000e+03      NaN      1.000000e+00  1.000000e+00
# 25%     6.750000e+03      NaN      6.000000e+00  7.800000e+01
# 50%     1.321000e+04      NaN      1.300000e+01  1.720000e+02
# 75%     1.850000e+04      NaN      1.800000e+01  2.790000e+02
# max     8.216000e+04      NaN      2.500000e+01  8.340000e+02

# %%
display(df_text['Code departement'].value_counts())
# Out:
# Code departement
# 13    108534
# 6     106001
# 22     70624
# 17     70528
# 24     67340
# 14     58688
# 1      50804
# 16     43776
# 21     42660
# 11     40077
# 7      36126
# 2      35193
# 3      33569
# 12     31921
# 18     29712
# 9      28732
# 19     27455
# 10     25320
# 23     23021
# 25     20037
# 5      19094
# 8      18146
# 4      16715
# 15     15619
# Name: count, dtype: int64

# %%
display(df_text['Commune'].value_counts())
# Out:
# Commune
# NICE                        26624
# DIJON                       12559
# SAINT-BRIEUC                10426
# CANNES                       9715
# AIX EN PROVENCE              9675
#                             ...
# OULCHES LA VALLEE FOULON        1
# SACHY                           1
# BATTENANS LES MINES             1
# CORCELLE-MIESLOT                1
# PAROY                           1
# Name: count, Length: 8484, dtype: int64

# %%
df_text.head()
# Out:
#    Identifiant de document  Reference document  1 Articles CGI  \
# 0                      NaN                 NaN             NaN
# 1                      NaN                 NaN             NaN
# 2                      NaN                 NaN             NaN
# 3                      NaN                 NaN             NaN
# 4                      NaN                 NaN             NaN
#
#    2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    No disposition Date mutation Nature mutation  ...  \
# 0               1    03/01/2022           Vente  ...
# 1               1    03/01/2022           Vente  ...
# ...

# %%
df_text.tail()
# Out:
#          Identifiant de document  Reference document  1 Articles CGI  \
# 1019687                      NaN                 NaN             NaN
# 1019688                      NaN                 NaN             NaN
# 1019689                      NaN                 NaN             NaN
# 1019690                      NaN                 NaN             NaN
# 1019691                      NaN                 NaN             NaN
#
#          2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 1019687             NaN             NaN             NaN             NaN
# 1019688             NaN             NaN             NaN             NaN
# 1019689             NaN             NaN             NaN             NaN
# 1019690             NaN             NaN             NaN             NaN
# 1019691             NaN             NaN             NaN             NaN
#
#          No disposition Date mutation Nature mutation  ...  \
# ...

# %%
df_text.describe()
# Out:
#        Identifiant de document  Reference document  1 Articles CGI  \
# count                      0.0                 0.0             0.0
# mean                       NaN                 NaN             NaN
# std                        NaN                 NaN             NaN
# min                        NaN                 NaN             NaN
# 25%                        NaN                 NaN             NaN
# 50%                        NaN                 NaN             NaN
# 75%                        NaN                 NaN             NaN
# max                        NaN                 NaN             NaN
#
#        2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# count             0.0             0.0             0.0             0.0
# mean              NaN             NaN             NaN             NaN
# std               NaN             NaN             NaN             NaN
# min               NaN             NaN             NaN             NaN
# ...

# %%
# !wget https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20231010-093059/valeursfoncieres-2022.txt
# Out:
# --2023-12-30 10:08:35--  https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20231010-093059/valeursfoncieres-2022.txt
# Résolution de static.data.gouv.fr (static.data.gouv.fr)… 37.59.183.93
# Connexion à static.data.gouv.fr (static.data.gouv.fr)|37.59.183.93|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 619422431 (591M) [text/plain]
# Sauvegarde en : « valeursfoncieres-2022.txt »
#
# valeursfoncieres-20  21%[===>                ] 128,39M  8,69MB/s    ds 6,8s
#
#
# Impossible d’écrire dans « valeursfoncieres-2022.txt » (No space left on device).
